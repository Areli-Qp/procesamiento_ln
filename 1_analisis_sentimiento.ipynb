# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set_style('darkgrid')

# %%
df = pd.read_csv("./data/IMDB Dataset.csv")

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df.sample(5)
# Out:
#                                                   review sentiment
# 36929  Loretta Castorini (Cher)is a woman in her late...  positive
# 21741  Some films are just plain silly beyond explana...  negative
# 45486  Plague replaces femme fatale in this highly su...  positive
# 44163  I went to a screening of this movie and while ...  negative
# 25607  <br /><br />**********SPOILER ALERT***********...  negative

# %%
df_pos = df[df['sentiment']=='positive'][:5000]
df_neg = df[df['sentiment']=='negative'][:5000]

df_reviews = pd.concat([df_pos, df_neg ])

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
train,test = train_test_split(df_reviews,test_size =0.33,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 train,test = train_test_split(df_reviews,test_size =0.33,random_state=42)
#
# NameError: name 'train_test_split' is not defined

# %%
train_x, train_y = train['review'], train['sentiment']
test_x, test_y = test['review'], test['sentiment']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_x, train_y = train['review'], train['sentiment']
#       2 test_x, test_y = test['review'], test['sentiment']
#
# NameError: name 'train' is not defined

# %%
train_y.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 train_y.value_counts()
#
# NameError: name 'train_y' is not defined

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from sklearn.feature_extraction.text import TfidfVectorizer
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
tfidf = TfidfVectorizer(stop_words='english')
train_x_vector = tfidf.fit_transform(train_x)
test_x_vector = tfidf.transform(test_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tfidf = TfidfVectorizer(stop_words='english')
#       2 train_x_vector = tfidf.fit_transform(train_x)
#       3 test_x_vector = tfidf.transform(test_x)
#
# NameError: name 'TfidfVectorizer' is not defined

# %%
train_x.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 train_x.shape
#
# NameError: name 'train_x' is not defined

# %%
train_x_vector.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 train_x_vector.shape
#
# NameError: name 'train_x_vector' is not defined

# %%
type(train_x_vector)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 type(train_x_vector)
#
# NameError: name 'train_x_vector' is not defined

# %%
primera_resenia = pd.DataFrame.sparse.from_spmatrix(train_x_vector,
                                  index=train_x.index,
                                  columns=tfidf.get_feature_names_out()).iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 primera_resenia = pd.DataFrame.sparse.from_spmatrix(train_x_vector,
#       2                                   index=train_x.index,
#       3                                   columns=tfidf.get_feature_names_out()).iloc[0]
#
# NameError: name 'train_x_vector' is not defined

# %%
primera_resenia
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 primera_resenia
#
# NameError: name 'primera_resenia' is not defined

# %%
train_x.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 train_x.iloc[0]
#
# NameError: name 'train_x' is not defined

# %%
primera_resenia[primera_resenia != 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 primera_resenia[primera_resenia != 0]
#
# NameError: name 'primera_resenia' is not defined

# %%
train_x.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 train_x.iloc[0]
#
# NameError: name 'train_x' is not defined

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear')
svc.fit(train_x_vector, train_y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from sklearn.svm import SVC
#       2 svc = SVC(kernel='linear')
#       3 svc.fit(train_x_vector, train_y)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
print(svc.predict(tfidf.transform(['A good movie'])))
print(svc.predict(tfidf.transform(['An excellent movie'])))
print(svc.predict(tfidf.transform(['I did not like this movie at all I gave this movie away'])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(svc.predict(tfidf.transform(['A good movie'])))
#       2 print(svc.predict(tfidf.transform(['An excellent movie'])))
#       3 print(svc.predict(tfidf.transform(['I did not like this movie at all I gave this movie away'])))
#
# NameError: name 'svc' is not defined

# %%
print(svc.score(test_x_vector, test_y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(svc.score(test_x_vector, test_y))
#
# NameError: name 'svc' is not defined

# %%
from sklearn.metrics import f1_score

f1_score(test_y,svc.predict(test_x_vector),
          labels = ['positive','negative'],average=None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from sklearn.metrics import f1_score
#       3 f1_score(test_y,svc.predict(test_x_vector),
#       4           labels = ['positive','negative'],average=None)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.metrics import classification_report

print(classification_report(test_y,
                            svc.predict(test_x_vector),
                            labels = ['positive','negative']))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from sklearn.metrics import classification_report
#       3 print(classification_report(test_y,
#       4                             svc.predict(test_x_vector),
#       5                             labels = ['positive','negative']))
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(test_y,
                           svc.predict(test_x_vector),
                           labels = ['positive', 'negative'])
conf_mat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 from sklearn.metrics import confusion_matrix
#       3 conf_mat = confusion_matrix(test_y,
#       4                            svc.predict(test_x_vector),
#       5                            labels = ['positive', 'negative'])
#       6 conf_mat
#
# ModuleNotFoundError: No module named 'sklearn'
